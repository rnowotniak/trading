# %%
# %matplotlib notebook
import talib
import talib.abstract as ta
import pandas as pd
import numpy as np
import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
from IPython.core.display import HTML
import seaborn as sns
import glob, os.path
sns.set_style('whitegrid')

# %%
us30 = pd.read_csv('data/US30Cash60.csv',
                   names=['day', 'hour', 'open', 'high', 'low', 'close', 'volume'], index_col=False)
us30['date'] = pd.DatetimeIndex(us30.day + ' ' + us30.hour)
del us30['day']
del us30['hour']
us30.set_index('date', inplace=True)
us30 = us30['2017/05/15':]

# %% [markdown]
# #  RSI dla

# %%
fig, axs = plt.subplots(nrows=2)# figsize=(14,14))
us30['close'].plot(legend=True, ax=axs[0])#figsize=(14,8))
ta.RSI(us30, 14).plot(legend=True, ax=axs[1], label='RSI')
plt.plot((us30.index.min(), us30.index.max()), (30,30), 'r-')
plt.plot((us30.index.min(), us30.index.max()), (70,70), 'r-')
#talib.SMA
# Out:
# <img src="data:image/png;base64,..." width="800">
